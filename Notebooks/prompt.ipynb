# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
import os 
load_dotenv()
if os.environ["GROQ_API_KEY"]:
    print("load env variable")
else:
    raise ValueError("not loaded")
# Out:
# load env variable

# %%
llm = ChatGroq(
    model_name="qwen/qwen3.6-27b",
    temperature=0.7
)

llm.invoke("I want to know the meaning of water").content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Query:** "I want to know the meaning of water"\n   - **Key Concept:** "meaning of water"\n   - **Ambiguity:** The word "meaning" can refer to:\n     - Scientific/chemical definition\n     - Biological/ecological importance\n     - Cultural/symbolic/spiritual significance\n     - Linguistic/etymological origin\n     - Philosophical/metaphorical interpretations\n   - **Goal:** Provide a comprehensive, well-structured answer that covers these dimensions while staying concise and clear.\n\n2.  **Identify Key Dimensions to Cover:**\n   - Scientific/Chemical\n   - Biological/Ecological\n   - Cultural/Symbolic/Spiritual\n   - Linguistic/Etymological\n   - Philosophical/Metaphorical (optional but useful)\n   - Practical/Everyday significance\n\n3.  **Draft - Section by Section:**\n   *(Scientific/Chemical)*\n   - Water is a chemical compound with the formula H₂O.\n   - It consists of two hydrogen atoms covalently 
# ...

# %% [markdown]
# ### **Prompt** ###

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that helps to create post and social media content for a given topic"),
    ("human", "I want to create a post about {topic}"),
])

# %%
prompt_filled = prompt.invoke({"topic": "Artificial Intelligence"})

# %%
llm.invoke(prompt_filled)
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Topic:** Artificial Intelligence (AI)\n   - **Goal:** Create a post/social media content\n   - **Missing Details:** Platform (LinkedIn, Twitter/X, Instagram, Facebook, etc.), tone (professional, casual, educational, inspirational, etc.), target audience, specific angle/focus within AI, length/format preferences.\n\n2.  **Identify Key Requirements:**\n   Since the request is broad, I need to:\n   - Provide versatile options across different platforms\n   - Offer different angles/focus areas within AI\n   - Include best practices for engagement\n   - Ask clarifying questions to tailor further if needed\n\n3.  **Brainstorming AI Post Angles:**\n   - Educational/Explainer: What is AI? How does it work?\n   - Trend/News: Latest AI breakthroughs, tools, or shifts\n   - Practical/How-to: How to use AI in daily work/life\n   - Thought Leadership/Opinion: AI ethics, future of work, human-AI collab
# ...
